# %% [markdown]
# ![Day 3.png](attachment:b6ea3f33-5211-4013-83ce-23e4b45002f1.png)

# %% [markdown]
# <img src='https://www.oreilly.com/api/v2/epubs/9781492050032/files/assets/lesp_0103.png'>

# %% [markdown]
# ---
# #### ✅ View this notebook and all others in this series on GitHub.
# #### ✅ Leave a comment below
# #### ✅ Subscribe
# #### ✅ Like
